# %% [markdown]
# ASISTENTE DE EJECUCIÓN DE CARGA DE DATOS
#
# Este notebook facilita la ejecución del csv_to_table_script.
#
# Para agregar los scripts al PATH de python:

# %%
import os
import sys

script_dir = os.path.abspath(os.path.join(os.getcwd(), '../scripts'))

if script_dir not in sys.path:
    sys.path.append(script_dir)

# %% [markdown]
# Una vez en el path, cargar datos (están en .../analisis-ecommerce/data/raw):

# %%
from csv_to_table_script import cargar_datos

path_csvs = os.path.abspath(os.path.join(os.getcwd(), '../data/raw'))

cargar_datos(path_csvs)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from csv_to_table_script import cargar_datos
#       3 path_csvs = os.path.abspath(os.path.join(os.getcwd(), '../data/geo'))
#       5 cargar_datos(path_csvs)
#
# ModuleNotFoundError: No module named 'csv_to_table_script'
